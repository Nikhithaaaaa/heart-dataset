# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\Hp\Downloads\heart.csv")
# Out:
#       age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52       1   0       125   212    0        1      168      0      1.0
# 1      53       1   0       140   203    1        0      155      1      3.1
# 2      70       1   0       145   174    0        1      125      1      2.6
# 3      61       1   0       148   203    0        1      161      0      0.0
# 4      62       0   0       138   294    1        1      106      0      1.9
# ...   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59       1   1       140   221    0        1      164      1      0.0
# 1021   60       1   0       125   258    0        0      141      1      2.8
# 1022   47       1   0       110   275    0        0      118      1      1.0
# 1023   50       0   0       110   254    0        0      159      0      0.0
# 1024   54       1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
dh = pd.read_csv(r"C:\Users\Hp\Downloads\heart.csv")

# %%
dh
# Out:
#       age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52       1   0       125   212    0        1      168      0      1.0
# 1      53       1   0       140   203    1        0      155      1      3.1
# 2      70       1   0       145   174    0        1      125      1      2.6
# 3      61       1   0       148   203    0        1      161      0      0.0
# 4      62       0   0       138   294    1        1      106      0      1.9
# ...   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59       1   1       140   221    0        1      164      1      0.0
# 1021   60       1   0       125   258    0        0      141      1      2.8
# 1022   47       1   0       110   275    0        0      118      1      1.0
# 1023   50       0   0       110   254    0        0      159      0      0.0
# 1024   54       1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
dh.isna().sum()
# Out:
# age         0
# gender      0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dh.dtypes
# Out:
# age           int64
# gender        int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
plt.boxplot(dh)
plt.show()

# %%
dh.columns
# Out:
# Index(['age', 'gender', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
dh["trestbps"]
# Out:
# 0       125
# 1       140
# 2       145
# 3       148
# 4       138
#        ...
# 1020    140
# 1021    125
# 1022    110
# 1023    110
# 1024    120
# Name: trestbps, Length: 1025, dtype: int64

# %%
sns.boxplot(dh["trestbps"])
# Out:
# <Axes: >

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
sns.distplot(dh["trestbps"])
# Out:
# <Axes: xlabel='trestbps', ylabel='Density'>

# %%
dh["trestbps"].skew()
# Out:
# 0.739768226050074

# %%
q1 = dh["trestbps"].quantile(0.25)
q1
# Out:
# 120.0

# %%
q3 = dh["trestbps"].quantile(0.75)
q3
# Out:
# 140.0

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# 20.0

# %%
lower = q1 - (1.5*iqr)
lower
# Out:
# 90.0

# %%
upper = q3 + (1.5*iqr)
upper
# Out:
# 170.0

# %%
dh["trestbps"].describe()
# Out:
# count    1025.000000
# mean      131.611707
# std        17.516718
# min        94.000000
# 25%       120.000000
# 50%       130.000000
# 75%       140.000000
# max       200.000000
# Name: trestbps, dtype: float64

# %%
dh["trestbps"] > upper
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1020    False
# 1021    False
# 1022    False
# 1023    False
# 1024    False
# Name: trestbps, Length: 1025, dtype: bool

# %%
dh[dh["trestbps"] > upper]
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 29    55       0   0       180   327    0        2      117      1      3.4
# 47    66       0   0       178   228    1        1      165      1      1.0
# 87    59       0   0       174   249    0        1      143      1      0.0
# 137   64       0   0       180   325    0        1      154      1      0.0
# 151   54       1   1       192   283    0        0      195      0      0.0
# 175   56       0   0       200   288    1        0      133      1      4.0
# 229   66       0   0       178   228    1        1      165      1      1.0
# 246   54       1   1       192   283    0        0      195      0      0.0
# 257   64       0   0       180   325    0        1      154      1      0.0
# 294   56       0   0       200   288    1        0      133      1      4.0
# 326   54       1   1       192   283    0        0      195      0      0.0
# ...

# %%
dh[dh["trestbps"] > upper].shape
# Out:
# (30, 14)

# %%
dh["trestbps"] < lower
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1020    False
# 1021    False
# 1022    False
# 1023    False
# 1024    False
# Name: trestbps, Length: 1025, dtype: bool

# %%
dh[dh["trestbps"] < lower]
# Out:
# Empty DataFrame
# Columns: [age, gender, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
dh[dh["trestbps"] < lower].shape
# Out:
# (0, 14)

# %%
(dh["trestbps"] < lower) | (dh["trestbps"] > upper)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1020    False
# 1021    False
# 1022    False
# 1023    False
# 1024    False
# Name: trestbps, Length: 1025, dtype: bool

# %%
dh[(dh["trestbps"] < lower) | (dh["trestbps"] > upper)]
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 29    55       0   0       180   327    0        2      117      1      3.4
# 47    66       0   0       178   228    1        1      165      1      1.0
# 87    59       0   0       174   249    0        1      143      1      0.0
# 137   64       0   0       180   325    0        1      154      1      0.0
# 151   54       1   1       192   283    0        0      195      0      0.0
# 175   56       0   0       200   288    1        0      133      1      4.0
# 229   66       0   0       178   228    1        1      165      1      1.0
# 246   54       1   1       192   283    0        0      195      0      0.0
# 257   64       0   0       180   325    0        1      154      1      0.0
# 294   56       0   0       200   288    1        0      133      1      4.0
# 326   54       1   1       192   283    0        0      195      0      0.0
# ...

# %%
dh[(dh["trestbps"] < lower) | (dh["trestbps"] > upper)].shape
# Out:
# (30, 14)

# %%
(dh["trestbps"] >= lower) & (dh["trestbps"] <= upper)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1020    True
# 1021    True
# 1022    True
# 1023    True
# 1024    True
# Name: trestbps, Length: 1025, dtype: bool

# %%
dh[(dh["trestbps"] >= lower) & (dh["trestbps"] <= upper)]
# Out:
#       age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52       1   0       125   212    0        1      168      0      1.0
# 1      53       1   0       140   203    1        0      155      1      3.1
# 2      70       1   0       145   174    0        1      125      1      2.6
# 3      61       1   0       148   203    0        1      161      0      0.0
# 4      62       0   0       138   294    1        1      106      0      1.9
# ...   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59       1   1       140   221    0        1      164      1      0.0
# 1021   60       1   0       125   258    0        0      141      1      2.8
# 1022   47       1   0       110   275    0        0      118      1      1.0
# 1023   50       0   0       110   254    0        0      159      0      0.0
# 1024   54       1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
dh[(dh["trestbps"] >= lower) & (dh["trestbps"] <= upper)].shape
# Out:
# (995, 14)

# %%
dh.shape
# Out:
# (1025, 14)

# %% [markdown]
# ## CAPPING

# %%
dh[(dh["trestbps"] < lower) | (dh["trestbps"] > upper)]
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 29    55       0   0       180   327    0        2      117      1      3.4
# 47    66       0   0       178   228    1        1      165      1      1.0
# 87    59       0   0       174   249    0        1      143      1      0.0
# 137   64       0   0       180   325    0        1      154      1      0.0
# 151   54       1   1       192   283    0        0      195      0      0.0
# 175   56       0   0       200   288    1        0      133      1      4.0
# 229   66       0   0       178   228    1        1      165      1      1.0
# 246   54       1   1       192   283    0        0      195      0      0.0
# 257   64       0   0       180   325    0        1      154      1      0.0
# 294   56       0   0       200   288    1        0      133      1      4.0
# 326   54       1   1       192   283    0        0      195      0      0.0
# ...

# %%
dh["trestbps"]
# Out:
# 0       125
# 1       140
# 2       145
# 3       148
# 4       138
#        ...
# 1020    140
# 1021    125
# 1022    110
# 1023    110
# 1024    120
# Name: trestbps, Length: 1025, dtype: int64

# %%
dh["trestbps"].map(lambda x : lower if x < lower else upper if x > upper else x)
# Out:
# 0       125.0
# 1       140.0
# 2       145.0
# 3       148.0
# 4       138.0
#         ...
# 1020    140.0
# 1021    125.0
# 1022    110.0
# 1023    110.0
# 1024    120.0
# Name: trestbps, Length: 1025, dtype: float64

# %%
dh["trestbps"] = dh["trestbps"].map(lambda x : lower if x < lower else upper if x > upper else x)

# %%
dh["trestbps"]
# Out:
# 0       125.0
# 1       140.0
# 2       145.0
# 3       148.0
# 4       138.0
#         ...
# 1020    140.0
# 1021    125.0
# 1022    110.0
# 1023    110.0
# 1024    120.0
# Name: trestbps, Length: 1025, dtype: float64

# %%
x = dh.drop("target" , axis = 1)

# %%
y = dh["target"]

# %%
x
# Out:
#       age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52       1   0     125.0   212    0        1      168      0      1.0
# 1      53       1   0     140.0   203    1        0      155      1      3.1
# 2      70       1   0     145.0   174    0        1      125      1      2.6
# 3      61       1   0     148.0   203    0        1      161      0      0.0
# 4      62       0   0     138.0   294    1        1      106      0      1.9
# ...   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59       1   1     140.0   221    0        1      164      1      0.0
# 1021   60       1   0     125.0   258    0        0      141      1      2.8
# 1022   47       1   0     110.0   275    0        0      118      1      1.0
# 1023   50       0   0     110.0   254    0        0      159      0      0.0
# 1024   54       1   0     120.0   188    0        1      113      0      1.4
#
#       slope  ca  thal
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
y.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
x.value_counts()
# Out:
# age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal
# 38   1       2   138.0     175   0    1        173      0      0.0      2      4   2       8
# 61   1       0   148.0     203   0    1        161      0      0.0      2      1   3       4
#                  138.0     166   0    0        125      1      3.6      1      1   2       4
# 52   1       0   112.0     230   0    1        160      0      0.0      2      1   2       4
#                  125.0     212   0    1        168      0      1.0      2      2   3       4
#                                                                                           ..
# 53   0       0   130.0     264   0    0        143      0      0.4      1      0   2       3
#                  138.0     234   0    0        160      0      0.0      2      0   2       3
#              2   128.0     216   0    0        115      0      0.0      2      0   0       3
# ...

# %%
dhzero = dh[dh["target"]==0]

# %%
dhones = dh[dh["target"]==1]

# %% [markdown]
# ## SPLITTING

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.20 , random_state=2)

# %%
x.shape , x_train.shape , x_test.shape
# Out:
# ((1025, 13), (820, 13), (205, 13))

# %%
y.shape , y_train.shape , y_test.shape
# Out:
# ((1025,), (820,), (205,))

# %%
x_train.head()
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 172   56       1   1     120.0   240    0        1      169      0      0.0
# 128   52       1   2     138.0   223    0        1      169      0      0.0
# 363   53       1   2     130.0   246    1        0      173      0      0.0
# 636   59       0   0     170.0   249    0        1      143      1      0.0
# 798   59       1   3     170.0   288    0        0      159      0      0.2
#
#      slope  ca  thal
# 172      0   0     2
# 128      2   4     2
# 363      2   3     2
# 636      1   0     2
# 798      1   0     3

# %%
x_test.head()
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 546   70       1   0     130.0   322    0        0      109      0      2.4
# 980   57       1   0     140.0   192    0        1      148      0      0.4
# 908   62       1   0     120.0   267    0        1       99      1      1.8
# 577   70       1   0     130.0   322    0        0      109      0      2.4
# 846   35       0   0     138.0   183    0        1      182      0      1.4
#
#      slope  ca  thal
# 546      1   3     2
# 980      1   0     1
# 908      1   2     3
# 577      1   3     2
# 846      2   0     2

# %% [markdown]
# ## DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dhmodel = DecisionTreeClassifier()

# %%
dhmodel
# Out:
# DecisionTreeClassifier()

# %%
dhmodel.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
dhmodel.score(x_test , y_test)
# Out:
# 0.9804878048780488

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC()

# %%
svm_model
# Out:
# SVC()

# %%
svm_model.fit(x_train , y_train)
# Out:
# SVC()

# %%
svm_model.score(x_test,y_test)
# Out:
# 0.7317073170731707

# %% [markdown]
# ## random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc_model = RandomForestClassifier()

# %%
rfc_model
# Out:
# RandomForestClassifier()

# %%
rfc_model.fit(x_train , y_train)
# Out:
# RandomForestClassifier()

# %%
rfc_model.score(x_test , y_test)
# Out:
# 1.0

# %% [markdown]
# ## logical regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
ir_model = LogisticRegression()

# %%
ir_model
# Out:
# LogisticRegression()

# %%
ir_model.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
ir_model.score(x_test , y_test)
# Out:
# 0.848780487804878

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier()

# %%
knn_model
# Out:
# KNeighborsClassifier()

# %%
knn_model.fit(x_train , y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_model.score(x_test , y_test)
# Out:
# 0.7024390243902439

# %% [markdown]
# ## ADABOOST

# %%
from sklearn.ensemble import AdaBoostClassifier , GradientBoostingClassifier

# %%
ab_model = AdaBoostClassifier()

# %%
ab_model
# Out:
# AdaBoostClassifier()

# %%
ab_model.fit(x_train , y_train)
# Out:
# AdaBoostClassifier()

# %%
ab_model.score(x_test , y_test)
# Out:
# 0.9073170731707317

# %% [markdown]
# ## AUTO ML

# %%
dt1 = DecisionTreeClassifier()

# %%
rfc1 = RandomForestClassifier()

# %%
svc1 = SVC()

# %%
knn1 = KNeighborsClassifier()

# %%
ada1 = AdaBoostClassifier()

# %%
gbc = GradientBoostingClassifier()

# %%
lr1 = LogisticRegression()

# %%
Model = [dt1 , rfc1 , svc1 , knn1 , ada1 , gbc , lr1]

# %%
Model
# Out:
# [DecisionTreeClassifier(),
#  RandomForestClassifier(),
#  SVC(),
#  KNeighborsClassifier(),
#  AdaBoostClassifier(),
#  GradientBoostingClassifier(),
#  LogisticRegression()]

# %%
for i in Model:
    print(i)
    i.fit(x_train , y_train)
    i.score(x_test , y_test)
    s = i.score(x_test , y_test)
    print(s)
# Out:
# DecisionTreeClassifier()
# 0.9804878048780488
# RandomForestClassifier()
# 1.0
# SVC()
# 0.7317073170731707
# KNeighborsClassifier()
# 0.7024390243902439
# AdaBoostClassifier()
# 0.9073170731707317
# GradientBoostingClassifier()
# 0.9707317073170731
# LogisticRegression()
# 0.848780487804878

# %%
score_list = []
for i in Model:
    i.fit(x_train , y_train)
    s = i.score(x_test , y_test)
    score_list.append(s)
r = max(score_list)
print(r)
i = score_list.index(r)
Model[i]
# Out:
# 1.0
# RandomForestClassifier()

# %%
print(Model)
# Out:
# [DecisionTreeClassifier(), RandomForestClassifier(), SVC(), KNeighborsClassifier(), AdaBoostClassifier(), GradientBoostingClassifier(), LogisticRegression()]

# %%
print(score_list)
# Out:
# [0.9804878048780488, 1.0, 0.7317073170731707, 0.7024390243902439, 0.9073170731707317, 0.9707317073170731, 0.848780487804878]
